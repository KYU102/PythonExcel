# %%
import pandas as pd 

df = pd.read_csv('kathleen.csv')
df
# Out:
#     Order Date             Order ID  \
# 0     12/29/15  110-3133051-9117065
# 1     03/28/16  113-6275972-1177835
# 2     04/07/16  113-9977289-3472202
# 3     06/22/16  113-5254773-2521014
# 4     06/22/16  113-5254773-2521014
# ..         ...                  ...
# 641   07/13/22  112-7586040-3155466
# 642   07/13/22  112-7586040-3155466
# 643   07/13/22  112-7586040-3155466
# 644   07/13/22  112-7586040-3155466
# 645   07/13/22  112-6281795-8125840
#
#                                                  Title  \
# 0         Estelle ID Please Wallet black Size one size
# 1                   Lifespan Development (7th Edition)
# 2                                     Seacret Mud Soap
# 3    Physical Therapy Gait Belt with Metal Buckle (...
# 4    LotFancy Aneroid Sphygmomanometer with Stethos...
# ..                                                 ...
# 641  Bose SoundLink Revolve (Series II) Portable Bl...
# 642  Ring Video Doorbell – 2020 release – 1080p HD ...
# 643  BOSHEL Dog Nail Clippers and Trimmer - with Sa...
# 644  Dog Bath Brush, Pet Massage Brush Shampoo Disp...
# 645  YDW 30 oz Stainless Steel Tumbler with Lid and...
#
#                    Category   ASIN/ISBN  UNSPSC Code     Website  \
# 0                    WALLET  B01090XZSY   53120000.0  Amazon.com
# 1                 ABIS_BOOK  0133805662   55101500.0  Amazon.com
# 2       SKIN_CLEANING_AGENT  B0030F3K9A   53131600.0  Amazon.com
# 3      HEALTH_PERSONAL_CARE  B012E4IV32   42000000.0  Amazon.com
# 4    BLOOD_PRESSURE_MONITOR  B0126MS5VA   42181602.0  Amazon.com
# ..                      ...         ...          ...         ...
# 641                SPEAKERS  B08VKXP1VY   52161512.0  Amazon.com
# 642             VDO_DEVICES  B08N5NQ869   46171610.0  Amazon.com
# 643            NAIL_CLIPPER  B00UJ2WLB0   10111300.0  Amazon.com
# 644                MASSAGER  B097R633S4   10111300.0  Amazon.com
# 645            DRINKING_CUP  B0993V16CM   52152100.0  Amazon.com
#
#             Release Date Condition             Seller  ...  \
# 0                    NaN       new       Bella Taylor  ...
# 1    2014-03-24T00:00:01       new   Amazon Warehouse  ...
# 2                    NaN       new          MLMRetail  ...
# 3                    NaN       new  MABUA EMPIRE, LLC  ...
# 4                    NaN       new           LotFancy  ...
# ..                   ...       ...                ...  ...
# 641                  NaN       new         Amazon.com  ...
# 642                  NaN       new         Amazon.com  ...
# 643                  NaN       new      Reveal A Deal  ...
# 644                  NaN       new          Woleigiao  ...
# 645                  NaN       new      YDW-cozy home  ...
#
#     Carrier Name & Tracking Number Item Subtotal Item Subtotal Tax  \
# 0     USPS(9400111699000200209524)        $11.95             $0.00
# 1          UPS(1ZY796501252886386)        $23.49             $2.26
# 2     USPS(9400111899223219896204)        $13.30             $0.00
# 3     USPS(9361289674090063171563)         $8.99             $0.85
# 4     USPS(9361289674090063171563)        $18.90             $0.00
# ..                             ...           ...               ...
# 641       AMZN_US(TBA173231123804)       $174.00            $13.49
# 642       AMZN_US(TBA177700756304)        $99.99             $5.81
# 643       AMZN_US(TBA177700756304)         $9.99             $0.77
# 644       AMZN_US(TBA177700756304)         $9.66             $0.75
# 645       AMZN_US(TBA173315173404)        $14.39             $1.12
#
#      Item Total Tax Exemption Applied  Tax Exemption Type  Exemption Opt-Out  \
# 0        $11.95                   NaN                 NaN                NaN
# 1        $25.75                   NaN                 NaN                NaN
# 2        $13.30                   NaN                 NaN                NaN
# 3         $9.84                   NaN                 NaN                NaN
# 4        $18.90                   NaN                 NaN                NaN
# ..          ...                   ...                 ...                ...
# 641     $187.49                 False                 NaN              False
# 642     $105.80                 False                 NaN              False
# 643      $10.76                 False                 NaN              False
# 644      $10.41                 False                 NaN              False
# 645      $15.51                 False                 NaN              False
#
#     Buyer Name Currency Group Name
# 0     Kathleen      USD        NaN
# 1     Kathleen      USD        NaN
# 2     Kathleen      USD        NaN
# 3     Kathleen      USD        NaN
# 4     Kathleen      USD        NaN
# ..         ...      ...        ...
# 641   Kathleen      USD        NaN
# 642   Kathleen      USD        NaN
# 643   Kathleen      USD        NaN
# 644   Kathleen      USD        NaN
# 645   Kathleen      USD        NaN
#
# [646 rows x 36 columns]

# %%
# cleaning data by replacing n/a items (NaN) with 0
# df = df.fillna(0)
# df.head()

# %%
# since the total charged has a '$' the column is stored as a string. Replace $ with nothing and convert the string into a float
df['Item Total'] = df['Item Total'].str.replace('$', '').astype(float)
df.head()
# Out:
# /var/folders/7l/pwm6xm1j3nd661z7sstj4nmm0000gn/T/ipykernel_80713/4219715528.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Item Total'] = df['Item Total'].str.replace('$', '').astype(float)
#   Order Date             Order ID  \
# 0   12/29/15  110-3133051-9117065
# 1   03/28/16  113-6275972-1177835
# 2   04/07/16  113-9977289-3472202
# 3   06/22/16  113-5254773-2521014
# 4   06/22/16  113-5254773-2521014
#
#                                                Title                Category  \
# 0       Estelle ID Please Wallet black Size one size                  WALLET
# 1                 Lifespan Development (7th Edition)               ABIS_BOOK
# 2                                   Seacret Mud Soap     SKIN_CLEANING_AGENT
# 3  Physical Therapy Gait Belt with Metal Buckle (...    HEALTH_PERSONAL_CARE
# 4  LotFancy Aneroid Sphygmomanometer with Stethos...  BLOOD_PRESSURE_MONITOR
#
#     ASIN/ISBN  UNSPSC Code     Website         Release Date Condition  \
# 0  B01090XZSY   53120000.0  Amazon.com                  NaN       new
# 1  0133805662   55101500.0  Amazon.com  2014-03-24T00:00:01       new
# 2  B0030F3K9A   53131600.0  Amazon.com                  NaN       new
# 3  B012E4IV32   42000000.0  Amazon.com                  NaN       new
# 4  B0126MS5VA   42181602.0  Amazon.com                  NaN       new
#
#               Seller  ... Carrier Name & Tracking Number Item Subtotal  \
# 0       Bella Taylor  ...   USPS(9400111699000200209524)        $11.95
# 1   Amazon Warehouse  ...        UPS(1ZY796501252886386)        $23.49
# 2          MLMRetail  ...   USPS(9400111899223219896204)        $13.30
# 3  MABUA EMPIRE, LLC  ...   USPS(9361289674090063171563)         $8.99
# 4           LotFancy  ...   USPS(9361289674090063171563)        $18.90
#
#   Item Subtotal Tax  Item Total Tax Exemption Applied  Tax Exemption Type  \
# 0             $0.00       11.95                   NaN                 NaN
# 1             $2.26       25.75                   NaN                 NaN
# 2             $0.00       13.30                   NaN                 NaN
# 3             $0.85        9.84                   NaN                 NaN
# 4             $0.00       18.90                   NaN                 NaN
#
#    Exemption Opt-Out Buyer Name Currency Group Name
# 0                NaN   Kathleen      USD        NaN
# 1                NaN   Kathleen      USD        NaN
# 2                NaN   Kathleen      USD        NaN
# 3                NaN   Kathleen      USD        NaN
# 4                NaN   Kathleen      USD        NaN
#
# [5 rows x 36 columns]

# %%
df['Item Total'].sum()
# Out:
# 19516.390000000003

# %%
df['Item Total'].max()
# Out:
# 371.27

# %%
df['Item Total'].min()
# Out:
# 0.0

# %%
df['Item Total'].median()
# Out:
# 19.65

# %%
# changing the date to pandas date time format
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
#   Order Date             Order ID  \
# 0 2015-12-29  110-3133051-9117065
# 1 2016-03-28  113-6275972-1177835
# 2 2016-04-07  113-9977289-3472202
# 3 2016-06-22  113-5254773-2521014
# 4 2016-06-22  113-5254773-2521014
#
#                                                Title                Category  \
# 0       Estelle ID Please Wallet black Size one size                  WALLET
# 1                 Lifespan Development (7th Edition)               ABIS_BOOK
# 2                                   Seacret Mud Soap     SKIN_CLEANING_AGENT
# 3  Physical Therapy Gait Belt with Metal Buckle (...    HEALTH_PERSONAL_CARE
# 4  LotFancy Aneroid Sphygmomanometer with Stethos...  BLOOD_PRESSURE_MONITOR
#
#     ASIN/ISBN  UNSPSC Code     Website         Release Date Condition  \
# 0  B01090XZSY   53120000.0  Amazon.com                  NaN       new
# 1  0133805662   55101500.0  Amazon.com  2014-03-24T00:00:01       new
# 2  B0030F3K9A   53131600.0  Amazon.com                  NaN       new
# 3  B012E4IV32   42000000.0  Amazon.com                  NaN       new
# 4  B0126MS5VA   42181602.0  Amazon.com                  NaN       new
#
#               Seller  ... Carrier Name & Tracking Number Item Subtotal  \
# 0       Bella Taylor  ...   USPS(9400111699000200209524)        $11.95
# 1   Amazon Warehouse  ...        UPS(1ZY796501252886386)        $23.49
# 2          MLMRetail  ...   USPS(9400111899223219896204)        $13.30
# 3  MABUA EMPIRE, LLC  ...   USPS(9361289674090063171563)         $8.99
# 4           LotFancy  ...   USPS(9361289674090063171563)        $18.90
#
#   Item Subtotal Tax  Item Total Tax Exemption Applied  Tax Exemption Type  \
# 0             $0.00       11.95                   NaN                 NaN
# 1             $2.26       25.75                   NaN                 NaN
# 2             $0.00       13.30                   NaN                 NaN
# 3             $0.85        9.84                   NaN                 NaN
# 4             $0.00       18.90                   NaN                 NaN
#
#    Exemption Opt-Out Buyer Name Currency Group Name
# 0                NaN   Kathleen      USD        NaN
# 1                NaN   Kathleen      USD        NaN
# 2                NaN   Kathleen      USD        NaN
# 3                NaN   Kathleen      USD        NaN
# 4                NaN   Kathleen      USD        NaN
#
# [5 rows x 36 columns]

# %%
#creating plot bar and setting x and y. rot = x axis rotataion. figsize is width and height of graph
df.plot.bar(x='Order Date', y='Item Total', rot=90, figsize=(60,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
#create a new variable dailt orders and group same date orders togetther can calculate the sum of money spent
daily_orders = df.groupby('Order Date').sum()['Item Total']
daily_orders.head()
# Out:
# Order Date
# 2015-12-29    11.95
# 2016-03-28    25.75
# 2016-04-07    13.30
# 2016-06-22    46.73
# 2016-08-07     0.99
# Name: Item Total, dtype: float64

# %%
daily_orders.plot.bar(figsize=(30,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>
